# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #Preprocessed

# %%
df = pd.read_csv('/content/drive/Shareddrives/Riddle mãi mận/DA/0. Final_term/Source code/Dataset/Preprocessed_Reviews.csv', encoding= 'unicode_escape')
df.head()
# Out:
#    Rating                                             Review  Sentiment  \
# 0       4  ['located 4 ton duc thang highclass villa oppo...          2
# 1       4  ['hana riverside quang ngai hotel located quie...          2
# 2       5  ['dropped 1 night way north friendly helpful s...          2
# 3       4  ['stayed one night passing room clean tidy ket...          2
# 4       4  ['nice hotel staff facilities work expanding b...          2
#
#    word_count
# 0          87
# 1          66
# 2          36
# 3         104
# 4          37

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83189 entries, 0 to 83188
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rating      83189 non-null  int64
#  1   Review      83189 non-null  object
#  2   Sentiment   83189 non-null  int64
#  3   word_count  83189 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 2.5+ MB

# %%
df.describe()
# Out:
#              Rating     Sentiment    word_count
# count  83189.000000  83189.000000  83189.000000
# mean       4.368859      1.757588    118.483189
# std        1.058891      0.592377    124.175255
# min        1.000000      0.000000      4.000000
# 25%        4.000000      2.000000     47.000000
# 50%        5.000000      2.000000     78.000000
# 75%        5.000000      2.000000    140.000000
# max        5.000000      2.000000   3687.000000

# %%
df_rating = pd.DataFrame(df.groupby('Rating')['Sentiment'].count()).reset_index()
df_rating
# Out:
#    Rating  Sentiment
# 0       1       3277
# 1       2       3680
# 2       3       6252
# 3       4      15852
# 4       5      54128

# %%
plt.pie(df_rating['Sentiment'],labels=df_rating['Rating'],autopct='%0.1f')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f891faaaf40>,
# ...
#  [Text(1.091587420013309, 0.1357825631982531, '1'),
#   Text(1.018864873302545, 0.4146255780221347, '2'),
#   Text(0.7961369540210773, 0.7590559600201037, '3'),
#   Text(-0.02805792092191043, 1.099642102264887, '4'),
#   Text(-0.501429687677115, -0.9790649969823408, '5')],
#  [Text(0.5954113200072595, 0.07406321628995623, '3.9'),
#   Text(0.5557444763468427, 0.2261594061938916, '4.4'),
#   Text(0.434256520375133, 0.41403052364732923, '7.5'),
#   Text(-0.015304320502860232, 0.5998047830535747, '19.1'),
#   Text(-0.27350710236933545, -0.5340354528994585, '65.1')])

# %%
df_sentiment = pd.DataFrame(df.groupby('Sentiment').count())
df_sentiment
# Out:
#            Rating  Review  word_count
# Sentiment
# 0            6957    6957        6957
# 1            6252    6252        6252
# 2           69980   69980       69980

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df.Review:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
df_review = pd.DataFrame(df.groupby('Sentiment')['Review']).reset_index()
df_review
# Out:
#    index  0                                                  1
# 0      0  0  7        ['visiting introduce area imperative ...
# 1      1  1  66       ['shabby hotel badest bathroom ever d...
# 2      2  2  0        ['located 4 ton duc thang highclass v...

# %%
df_review.iloc[0]
# Out:
# index                                                    0
# 0                                                        0
# 1        7        ['visiting introduce area imperative ...
# Name: 0, dtype: object

# %%
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df_review.iloc[0]:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 400, height = 600,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df_review.iloc[1]:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 400, height = 600,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df_review.iloc[2]:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 1000, height = 1500,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
import seaborn as sns

# %%
sns.boxplot(x = df['Sentiment'], y = df['word_count'])
# Out:
# <Axes: xlabel='Sentiment', ylabel='word_count'>

# %% [markdown]
# #Train

# %%
df_train = pd.read_csv('/content/drive/Shareddrives/Riddle mãi mận/DA/0. Final_term/Source code/Dataset/train.csv', encoding= 'unicode_escape')
df_train.head()
# Out:
#    Unnamed: 0  Rating                                             Review  \
# 0         600       5  ['maintenance work still donestill 5 pointsthe...
# 1       41569       5  ['second visit korean staff really friendly go...
# 2        3136       5  ['stay mine hotel extremely comfy rooms huge l...
# 3       31573       5  ['vinpearl discovery overall satisfaction fami...
# 4       29525       4  ['location hotel little bit away town issue we...
#
#    Sentiment  word_count
# 0          2          95
# 1          2          16
# 2          2          58
# 3          2          32
# 4          2         191

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66551 entries, 0 to 66550
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  66551 non-null  int64
#  1   Rating      66551 non-null  int64
#  2   Review      66551 non-null  object
#  3   Sentiment   66551 non-null  int64
#  4   word_count  66551 non-null  int64
# dtypes: int64(4), object(1)
# memory usage: 2.5+ MB

# %%
df_train.describe()
# Out:
#          Unnamed: 0        Rating     Sentiment    word_count
# count  66551.000000  66551.000000  66551.000000  66551.000000
# mean   41561.764692      4.365975      1.756052    118.090367
# std    24021.000359      1.063190      0.594269    124.047969
# min        0.000000      1.000000      0.000000      4.000000
# 25%    20753.500000      4.000000      2.000000     47.000000
# 50%    41556.000000      5.000000      2.000000     78.000000
# 75%    62356.500000      5.000000      2.000000    139.000000
# max    83188.000000      5.000000      2.000000   3687.000000

# %%
df_rating_train = pd.DataFrame(df_train.groupby('Rating')['Sentiment'].count()).reset_index()
df_rating_train
# Out:
#    Rating  Sentiment
# 0       1       2681
# 1       2       2933
# 2       3       5007
# 3       4      12658
# 4       5      43272

# %%
df_sentiment_train = pd.DataFrame(df_train.groupby('Sentiment').count())
df_sentiment_train
# Out:
#            Unnamed: 0  Rating  Review  word_count
# Sentiment
# 0                5614    5614    5614        5614
# 1                5007    5007    5007        5007
# 2               55930   55930   55930       55930

# %%
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df_train.Review:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

# %%
df_train_review = pd.DataFrame(df_train.groupby('Sentiment')['Review']).reset_index()
df_train_review
# Out:
#    index  0                                                  1
# 0      0  0  8        ['hotel outright lied booking detail ...
# 1      1  1  15       ['good money boyfriend got punta cana...
# 2      2  2  0        ['maintenance work still donestill 5 ...

# %%
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df_train_review.iloc[0]:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 400, height = 600,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df_train_review.iloc[1]:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 400, height = 600,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df_train_review.iloc[2]:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 400, height = 600,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
sns.boxplot(x = df_train['Sentiment'], y = df_train['word_count'])
# Out:
# <Axes: xlabel='Sentiment', ylabel='word_count'>
